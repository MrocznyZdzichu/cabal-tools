# %%
# %load_ext autoreload
# %autoreload 2

# %%
import CabalTools
main = CabalTools.CabalTools(modules=['OVLManager'])

# %%
new_ovl = [
    { 'Mastery_index' : 1,  'Overloadmastery_lv' : 1, 'forcecode_value' : 10},  # All Attack I
    { 'Mastery_index' : 1,  'Overloadmastery_lv' : 2, 'forcecode_value' : 20},  # All Attack I
    { 'Mastery_index' : 1,  'Overloadmastery_lv' : 3, 'forcecode_value' : 30},  # All Attack I
    { 'Mastery_index' : 1,  'Overloadmastery_lv' : 4, 'forcecode_value' : 60},  # All Attack I
    { 'Mastery_index' : 1,  'Overloadmastery_lv' : 5, 'forcecode_value' : 100}, # All Attack I
    { 'Mastery_index' : 2,  'Overloadmastery_lv' : 1, 'forcecode_value' : 1},   # CD I
    { 'Mastery_index' : 2,  'Overloadmastery_lv' : 2, 'forcecode_value' : 2},   # CD I
    { 'Mastery_index' : 2,  'Overloadmastery_lv' : 3, 'forcecode_value' : 4},   # CD I
    { 'Mastery_index' : 2,  'Overloadmastery_lv' : 4, 'forcecode_value' : 6},   # CD I
    { 'Mastery_index' : 2,  'Overloadmastery_lv' : 5, 'forcecode_value' : 10},  # CD I
    { 'Mastery_index' : 3,  'Overloadmastery_lv' : 1, 'forcecode_value' : 10},  # Att. Rate I
    { 'Mastery_index' : 3,  'Overloadmastery_lv' : 2, 'forcecode_value' : 50},  # Att. Rate I
    { 'Mastery_index' : 3,  'Overloadmastery_lv' : 3, 'forcecode_value' : 100}, # Att. Rate I
    { 'Mastery_index' : 3,  'Overloadmastery_lv' : 4, 'forcecode_value' : 200}, # Att. Rate I
    { 'Mastery_index' : 3,  'Overloadmastery_lv' : 5, 'forcecode_value' : 300}, # Att. Rate I
    { 'Mastery_index' : 4,  'Overloadmastery_lv' : 1, 'forcecode_value' : 10},  # Add Damage I
    { 'Mastery_index' : 4,  'Overloadmastery_lv' : 2, 'forcecode_value' : 20},  # Add Damage I
    { 'Mastery_index' : 4,  'Overloadmastery_lv' : 3, 'forcecode_value' : 60},  # Add Damage I
    { 'Mastery_index' : 4,  'Overloadmastery_lv' : 4, 'forcecode_value' : 100}, # Add Damage I
    { 'Mastery_index' : 4,  'Overloadmastery_lv' : 5, 'forcecode_value' : 200}, # Add Damage I
    { 'Mastery_index' : 5,  'Overloadmastery_lv' : 1, 'forcecode_value' : 10},  # All Attack II
    { 'Mastery_index' : 5,  'Overloadmastery_lv' : 2, 'forcecode_value' : 20},  # All Attack II
    { 'Mastery_index' : 5,  'Overloadmastery_lv' : 3, 'forcecode_value' : 60},  # All Attack II
    { 'Mastery_index' : 5,  'Overloadmastery_lv' : 4, 'forcecode_value' : 100}, # All Attack II
    { 'Mastery_index' : 5,  'Overloadmastery_lv' : 5, 'forcecode_value' : 200}, # All Attack II
    { 'Mastery_index' : 6,  'Overloadmastery_lv' : 1, 'forcecode_value' : 3},   # CD II
    { 'Mastery_index' : 6,  'Overloadmastery_lv' : 2, 'forcecode_value' : 6},   # CD II
    { 'Mastery_index' : 6,  'Overloadmastery_lv' : 3, 'forcecode_value' : 15},  # CD II
    { 'Mastery_index' : 7,  'Overloadmastery_lv' : 1, 'forcecode_value' : 10},  # Accuracy I
    { 'Mastery_index' : 7,  'Overloadmastery_lv' : 2, 'forcecode_value' : 50},  # Accuracy I
    { 'Mastery_index' : 7,  'Overloadmastery_lv' : 3, 'forcecode_value' : 100}, # Accuracy I
    { 'Mastery_index' : 7,  'Overloadmastery_lv' : 4, 'forcecode_value' : 200}, # Accuracy I
    { 'Mastery_index' : 7,  'Overloadmastery_lv' : 5, 'forcecode_value' : 300}, # Accuracy I
    { 'Mastery_index' : 8,  'Overloadmastery_lv' : 1, 'forcecode_value' : 1},   # IRCR
    { 'Mastery_index' : 8,  'Overloadmastery_lv' : 2, 'forcecode_value' : 2},   # IRCR
    { 'Mastery_index' : 8,  'Overloadmastery_lv' : 3, 'forcecode_value' : 3},   # IRCR
    { 'Mastery_index' : 8,  'Overloadmastery_lv' : 4, 'forcecode_value' : 6},   # IRCR
    { 'Mastery_index' : 8,  'Overloadmastery_lv' : 5, 'forcecode_value' : 10},  # IRCR
    { 'Mastery_index' : 9,  'Overloadmastery_lv' : 1, 'forcecode_value' : 30},  # Att. Rate II
    { 'Mastery_index' : 9,  'Overloadmastery_lv' : 2, 'forcecode_value' : 60},  # Att. Rate II
    { 'Mastery_index' : 9,  'Overloadmastery_lv' : 3, 'forcecode_value' : 100}, # Att. Rate II
    { 'Mastery_index' : 9,  'Overloadmastery_lv' : 4, 'forcecode_value' : 150}, # Att. Rate II
    { 'Mastery_index' : 9,  'Overloadmastery_lv' : 5, 'forcecode_value' : 350}, # Att. Rate II
    { 'Mastery_index' : 10, 'Overloadmastery_lv' : 1, 'forcecode_value' : 2},   # Pene I
    { 'Mastery_index' : 10, 'Overloadmastery_lv' : 2, 'forcecode_value' : 4},   # Pene I
    { 'Mastery_index' : 10, 'Overloadmastery_lv' : 3, 'forcecode_value' : 8},   # Pene I
    { 'Mastery_index' : 10, 'Overloadmastery_lv' : 4, 'forcecode_value' : 12},  # Pene I
    { 'Mastery_index' : 10, 'Overloadmastery_lv' : 5, 'forcecode_value' : 20},  # Pene I
    { 'Mastery_index' : 11, 'Overloadmastery_lv' : 1, 'forcecode_value' : 20},  # All Attack III
    { 'Mastery_index' : 11, 'Overloadmastery_lv' : 2, 'forcecode_value' : 48},  # All Attack III
    { 'Mastery_index' : 11, 'Overloadmastery_lv' : 3, 'forcecode_value' : 96},  # All Attack III
    { 'Mastery_index' : 11, 'Overloadmastery_lv' : 4, 'forcecode_value' : 164}, # All Attack III
    { 'Mastery_index' : 11, 'Overloadmastery_lv' : 5, 'forcecode_value' : 250}, # All Attack III
    { 'Mastery_index' : 12, 'Overloadmastery_lv' : 1, 'forcecode_value' : 10},  # Accuracy II
    { 'Mastery_index' : 12, 'Overloadmastery_lv' : 2, 'forcecode_value' : 50},  # Accuracy II
    { 'Mastery_index' : 12, 'Overloadmastery_lv' : 3, 'forcecode_value' : 100}, # Accuracy II
    { 'Mastery_index' : 12, 'Overloadmastery_lv' : 4, 'forcecode_value' : 200}, # Accuracy II
    { 'Mastery_index' : 12, 'Overloadmastery_lv' : 5, 'forcecode_value' : 300}, # Accuracy II
    { 'Mastery_index' : 13, 'Overloadmastery_lv' : 1, 'forcecode_value' : 10},  # Add Damage II
    { 'Mastery_index' : 13, 'Overloadmastery_lv' : 2, 'forcecode_value' : 50},  # Add Damage II
    { 'Mastery_index' : 13, 'Overloadmastery_lv' : 3, 'forcecode_value' : 100}, # Add Damage II
    { 'Mastery_index' : 13, 'Overloadmastery_lv' : 4, 'forcecode_value' : 200}, # Add Damage II
    { 'Mastery_index' : 13, 'Overloadmastery_lv' : 5, 'forcecode_value' : 300}, # Add Damage II
    { 'Mastery_index' : 14, 'Overloadmastery_lv' : 1, 'forcecode_value' : 10},  # Penetration II
    { 'Mastery_index' : 14, 'Overloadmastery_lv' : 2, 'forcecode_value' : 25},  # Penetration II
    { 'Mastery_index' : 14, 'Overloadmastery_lv' : 3, 'forcecode_value' : 40},  # Penetration II
    { 'Mastery_index' : 15, 'Overloadmastery_lv' : 1, 'forcecode_value' : 10},  # Defense I
    { 'Mastery_index' : 15, 'Overloadmastery_lv' : 2, 'forcecode_value' : 30},  # Defense I
    { 'Mastery_index' : 15, 'Overloadmastery_lv' : 3, 'forcecode_value' : 50},  # Defense I
    { 'Mastery_index' : 15, 'Overloadmastery_lv' : 4, 'forcecode_value' : 70},  # Defense I
    { 'Mastery_index' : 15, 'Overloadmastery_lv' : 5, 'forcecode_value' : 100}, # Defense I
    { 'Mastery_index' : 16, 'Overloadmastery_lv' : 1, 'forcecode_value' : 20},  # HP I
    { 'Mastery_index' : 16, 'Overloadmastery_lv' : 2, 'forcecode_value' : 60},  # HP I
    { 'Mastery_index' : 16, 'Overloadmastery_lv' : 3, 'forcecode_value' : 100}, # HP I
    { 'Mastery_index' : 16, 'Overloadmastery_lv' : 4, 'forcecode_value' : 200}, # HP I
    { 'Mastery_index' : 16, 'Overloadmastery_lv' : 5, 'forcecode_value' : 300}, # HP I
    { 'Mastery_index' : 17, 'Overloadmastery_lv' : 1, 'forcecode_value' : 2},   # Resist Knock Back
    { 'Mastery_index' : 17, 'Overloadmastery_lv' : 2, 'forcecode_value' : 6},   # Resist Knock Back
    { 'Mastery_index' : 17, 'Overloadmastery_lv' : 3, 'forcecode_value' : 10},  # Resist Knock Back
    { 'Mastery_index' : 17, 'Overloadmastery_lv' : 4, 'forcecode_value' : 20},  # Resist Knock Back
    { 'Mastery_index' : 17, 'Overloadmastery_lv' : 5, 'forcecode_value' : 30},  # Resist Knock Back
    { 'Mastery_index' : 18, 'Overloadmastery_lv' : 1, 'forcecode_value' : 20},  # Ignore Accuracy I
    { 'Mastery_index' : 18, 'Overloadmastery_lv' : 2, 'forcecode_value' : 60},  # Ignore Accuracy I
    { 'Mastery_index' : 18, 'Overloadmastery_lv' : 3, 'forcecode_value' : 100}, # Ignore Accuracy I
    { 'Mastery_index' : 18, 'Overloadmastery_lv' : 4, 'forcecode_value' : 200}, # Ignore Accuracy I
    { 'Mastery_index' : 18, 'Overloadmastery_lv' : 5, 'forcecode_value' : 300}, # Ignore Accuracy I
    { 'Mastery_index' : 19, 'Overloadmastery_lv' : 1, 'forcecode_value' : 10},  # DMG Reduction I
    { 'Mastery_index' : 19, 'Overloadmastery_lv' : 2, 'forcecode_value' : 20},  # DMG Reduction I
    { 'Mastery_index' : 19, 'Overloadmastery_lv' : 3, 'forcecode_value' : 40},  # DMG Reduction I
    { 'Mastery_index' : 19, 'Overloadmastery_lv' : 4, 'forcecode_value' : 60},  # DMG Reduction I
    { 'Mastery_index' : 19, 'Overloadmastery_lv' : 5, 'forcecode_value' : 100}, # DMG Reduction I
    { 'Mastery_index' : 20, 'Overloadmastery_lv' : 1, 'forcecode_value' : 6},   # Resist CD
    { 'Mastery_index' : 20, 'Overloadmastery_lv' : 2, 'forcecode_value' : 10},  # Resist CD
    { 'Mastery_index' : 20, 'Overloadmastery_lv' : 3, 'forcecode_value' : 16},  # Resist CD
    { 'Mastery_index' : 20, 'Overloadmastery_lv' : 4, 'forcecode_value' : 24},  # Resist CD
    { 'Mastery_index' : 20, 'Overloadmastery_lv' : 5, 'forcecode_value' : 40},  # Resist CD
    { 'Mastery_index' : 21, 'Overloadmastery_lv' : 1, 'forcecode_value' : 2},   # Resist Down
    { 'Mastery_index' : 21, 'Overloadmastery_lv' : 2, 'forcecode_value' : 6},   # Resist Down
    { 'Mastery_index' : 21, 'Overloadmastery_lv' : 3, 'forcecode_value' : 10},  # Resist Down
    { 'Mastery_index' : 21, 'Overloadmastery_lv' : 4, 'forcecode_value' : 20},  # Resist Down
    { 'Mastery_index' : 21, 'Overloadmastery_lv' : 5, 'forcecode_value' : 30},  # Resist Down
    { 'Mastery_index' : 22, 'Overloadmastery_lv' : 1, 'forcecode_value' : 24},  # HP II
    { 'Mastery_index' : 22, 'Overloadmastery_lv' : 2, 'forcecode_value' : 64},  # HP II
    { 'Mastery_index' : 22, 'Overloadmastery_lv' : 3, 'forcecode_value' : 124}, # HP II
    { 'Mastery_index' : 22, 'Overloadmastery_lv' : 4, 'forcecode_value' : 264}, # HP II
    { 'Mastery_index' : 22, 'Overloadmastery_lv' : 5, 'forcecode_value' : 400}, # HP II
    { 'Mastery_index' : 23, 'Overloadmastery_lv' : 1, 'forcecode_value' : 2},   # Resist Stun
    { 'Mastery_index' : 23, 'Overloadmastery_lv' : 2, 'forcecode_value' : 6},   # Resist Stun
    { 'Mastery_index' : 23, 'Overloadmastery_lv' : 3, 'forcecode_value' : 10},  # Resist Stun
    { 'Mastery_index' : 23, 'Overloadmastery_lv' : 4, 'forcecode_value' : 20},  # Resist Stun
    { 'Mastery_index' : 23, 'Overloadmastery_lv' : 5, 'forcecode_value' : 30},  # Resist Stun
    { 'Mastery_index' : 24, 'Overloadmastery_lv' : 1, 'forcecode_value' : 10},  # Ignore Penetration I
    { 'Mastery_index' : 24, 'Overloadmastery_lv' : 2, 'forcecode_value' : 20},  # Ignore Penetration I
    { 'Mastery_index' : 24, 'Overloadmastery_lv' : 3, 'forcecode_value' : 40},  # Ignore Penetration I
    { 'Mastery_index' : 24, 'Overloadmastery_lv' : 4, 'forcecode_value' : 60},  # Ignore Penetration I
    { 'Mastery_index' : 24, 'Overloadmastery_lv' : 5, 'forcecode_value' : 100}, # Ignore Penetration I
    { 'Mastery_index' : 25, 'Overloadmastery_lv' : 1, 'forcecode_value' : 20},  # Defence II
    { 'Mastery_index' : 25, 'Overloadmastery_lv' : 2, 'forcecode_value' : 60},  # Defence II
    { 'Mastery_index' : 25, 'Overloadmastery_lv' : 3, 'forcecode_value' : 100}, # Defence II
    { 'Mastery_index' : 25, 'Overloadmastery_lv' : 4, 'forcecode_value' : 140}, # Defence II
    { 'Mastery_index' : 25, 'Overloadmastery_lv' : 5, 'forcecode_value' : 200}, # Defence II
    { 'Mastery_index' : 26, 'Overloadmastery_lv' : 1, 'forcecode_value' : 5},   # Resist Skill Amp
    { 'Mastery_index' : 26, 'Overloadmastery_lv' : 2, 'forcecode_value' : 10},  # Resist Skill Amp
    { 'Mastery_index' : 26, 'Overloadmastery_lv' : 3, 'forcecode_value' : 16},  # Resist Skill Amp
    { 'Mastery_index' : 26, 'Overloadmastery_lv' : 4, 'forcecode_value' : 24},  # Resist Skill Amp
    { 'Mastery_index' : 26, 'Overloadmastery_lv' : 5, 'forcecode_value' : 40},  # Resist Skill Amp
    { 'Mastery_index' : 27, 'Overloadmastery_lv' : 1, 'forcecode_value' : 50},  # Ignore Accuracy II
    { 'Mastery_index' : 27, 'Overloadmastery_lv' : 2, 'forcecode_value' : 100}, # Ignore Accuracy II
    { 'Mastery_index' : 27, 'Overloadmastery_lv' : 3, 'forcecode_value' : 200}, # Ignore Accuracy II
    { 'Mastery_index' : 27, 'Overloadmastery_lv' : 4, 'forcecode_value' : 300}, # Ignore Accuracy II
    { 'Mastery_index' : 27, 'Overloadmastery_lv' : 5, 'forcecode_value' : 400}, # Ignore Accuracy II
    { 'Mastery_index' : 28, 'Overloadmastery_lv' : 1, 'forcecode_value' : 50},  # Ignore Penetration II
    { 'Mastery_index' : 28, 'Overloadmastery_lv' : 2, 'forcecode_value' : 100}, # Ignore Penetration II
    { 'Mastery_index' : 28, 'Overloadmastery_lv' : 3, 'forcecode_value' : 200}, # Ignore Penetration II
]
for ovl_conf in new_ovl:
    main.OVLManager.modify_stat(**ovl_conf, save_files=False, do_reinit=False)

main.OVLManager.reinit()
main.OVLManager.save()

# %%
sink = main.OVLManager.preview(section_name='Overloadmastery_Value')

# %%
main.backup('ovl')
